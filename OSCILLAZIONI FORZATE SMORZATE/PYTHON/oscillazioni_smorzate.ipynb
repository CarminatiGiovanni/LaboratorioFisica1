# %% [markdown]
# # OSCILLAZIONI SMORZATE
#
# la raccolta dati viene interpolata con una sinusoide smorzata, raccogliamo misurazioni di $\gamma$ e $\omega$
#
# $\theta (t) = A_0 e^{-\gamma t} \sin (\omega t + \phi) + \theta_0$  $
#
# $\omega = \sqrt{\omega_0^2 - \gamma^2} \Rightarrow \omega_0 = \sqrt{\omega^2 +\gamma^2}$

# %%
import numpy as np
import pandas as pd
import os
from interpolazione3 import final_val

FILE = os.path.abspath('') + '/../CSV/oscillazioni_smorzate.csv'
fr = pd.read_csv(FILE)

omega = np.array(fr['omega']) # rad/s
gamma = np.array(fr['gamma'])

omega_m = np.average(omega)
omega_sm = 0.01 # errore dello strumento di misura
omega_std = np.sqrt(np.std(omega)**2 + omega_sm**2)
omega_mstd = omega_std/np.sqrt(len(omega))

gamma_m = np.average(gamma)
gamma_sm = 0.001 # errore dello strumento di misura
gamma_std = np.sqrt(np.std(gamma)**2 + gamma_sm**2)
gamma_mstd = gamma_std/np.sqrt(len(gamma))

omega_zero = np.sqrt(omega_m**2 + gamma_m**2)


n = np.sqrt((2*omega_m*omega_mstd)**2 + (2*gamma_m*gamma_mstd)**2)
s = 2*np.sqrt(omega_m**2 + gamma_m**2)

sigma_omega_zero = n/s
print("omega_0 : ",final_val(omega_zero, sigma_omega_zero)) 
# TODO: propagare l'errore
# Out:
# omega_0 :  2.58 ± 0.01

# %% [markdown]
# ### nota propagazione dell'errore:
#
# =(SQRT(POWER(2*C2*C5,2)+POWER(2*D2*D5,2)))/(2*SQRT(C2*C2+D2*D2))
#
# $\sigma_{\omega_0} = \frac{\sqrt{(2\omega\sigma_\omega)^2 + (2\gamma\sigma_\gamma)^2}}{2\sqrt{\omega^2 + \gamma^2}}$
